# %% [markdown]
# <a href="https://colab.research.google.com/github/dan9133/Fundamental_Of-_Web_Scrape_/blob/main/Basic_web_scrape.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Web_Scraping_using_Python**
#
# **Open URl and putt (url/robots.txt)like:https://www.sarkariresult.com/robots.txt**

# %% [markdown]
# **BASH CMD**
#
# **pip install requests**
#
# **pip install BeautiufulSoup**

# %%
import requests
web=requests.get("https://www.sarkariresult.com/")
print(web)

# If will response 200 then the url is ready to scrape.
# Out:
# <Response [200]>

# %% [markdown]
# **# Show all HTML CODE :**

# %%
web.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head><meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<title>SarkariResult.com : Sarkari Results, Latest Online Form | Result 2024</title>\n<meta name="description" content="Sarkari Result, Sarkari Results : SarkariResult.com provides latest Sarkari Result Jobs, Online Form, Sarkari Naukri Result in Sarkari Result 2024 various sectors such as Railway, Bank, SSC, Navy, Police, UPPSC, UPSSSC, UPTET, UP Scholarship and other sarkari result Com alerts at one place \xe0\xa4\xb8\xe0\xa4\xb0\xe0\xa4\x95\xe0\xa4\xbe\xe0\xa4\xb0\xe0\xa5\x80 \xe0\xa4\xb0\xe0\xa4\xbf\xe0\xa4\x9c\xe0\xa4\xb2\xe0\xa5\x8d\xe0\xa4\x9f  ">\n<meta name="keywords" content="Sarkari Result, Sarkari Results, sarkari result 2024,  latest sarkari result, Sarkariresult, Sarkari, Sarkariresults, Sarkari Naukri, sarkari results 2023, sarkari result 2024, Sarkari Exam, SarkariResult.com">\n\n<meta name="rating" content="general" />\n<meta http-equiv="content-language" c
# ...

# %%
# show the url
web.url
# Out:
# 'https://www.sarkariresult.com/'

# %%
web.status_code
# Out:
# 200

# %% [markdown]
# **How to Data Extrct From the URL Tag**

# %%
import requests
from bs4 import BeautifulSoup

# %%
web=requests.get("https://www.sarkariresult.com/")
web.status_code
# Out:
# 200

# %%
web.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head><meta http-equiv="Content-Type" content="text/html; charset=utf-8">\n<title>SarkariResult.com : Sarkari Results, Latest Online Form | Result 2024</title>\n<meta name="description" content="Sarkari Result, Sarkari Results : SarkariResult.com provides latest Sarkari Result Jobs, Online Form, Sarkari Naukri Result in Sarkari Result 2024 various sectors such as Railway, Bank, SSC, Navy, Police, UPPSC, UPSSSC, UPTET, UP Scholarship and other sarkari result Com alerts at one place \xe0\xa4\xb8\xe0\xa4\xb0\xe0\xa4\x95\xe0\xa4\xbe\xe0\xa4\xb0\xe0\xa5\x80 \xe0\xa4\xb0\xe0\xa4\xbf\xe0\xa4\x9c\xe0\xa4\xb2\xe0\xa5\x8d\xe0\xa4\x9f  ">\n<meta name="keywords" content="Sarkari Result, Sarkari Results, sarkari result 2024,  latest sarkari result, Sarkariresult, Sarkari, Sarkariresults, Sarkari Naukri, sarkari results 2023, sarkari result 2024, Sarkari Exam, SarkariResult.com">\n\n<meta name="rating" content="general" />\n<meta http-equiv="content-language" c
# ...

# %% [markdown]
# **To convert Into proper format**

# %%
soup=BeautifulSoup(web.content,"html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    SarkariResult.com : Sarkari Results, Latest Online Form | Result 2024
#   </title>
#   <meta content="Sarkari Result, Sarkari Results : SarkariResult.com provides latest Sarkari Result Jobs, Online Form, Sarkari Naukri Result in Sarkari Result 2024 various sectors such as Railway, Bank, SSC, Navy, Police, UPPSC, UPSSSC, UPTET, UP Scholarship and other sarkari result Com alerts at one place सरकारी रिजल्ट  " name="description"/>
#   <meta content="Sarkari Result, Sarkari Results, sarkari result 2024,  latest sarkari result, Sarkariresult, Sarkari, Sarkariresults, Sarkari Naukri, sarkari results 2023, sarkari result 2024, Sarkari Exam, SarkariResult.com" name="keywords"/>
#   <meta content="general" name="rating">
#    <meta content="en" http-equiv="content-language">
#     <meta content="global" name="distribution">
# ...

# %% [markdown]
# **Find Title**

# %%
soup.title
# Out:
# <title>SarkariResult.com : Sarkari Results, Latest Online Form | Result 2024</title>

# %%
soup.title.name
# Out:
# 'title'

# %%
# check first paragraph
soup.p
# Out:
# <p> The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.</p>

# %%
# check first anchor
soup.a
# Out:
# <a href="https://www.sarkariresult.com/">Home</a>

# %%
# check first heading
soup.h1
# Out:
# <h1>Sarkari Result : SarkariResult.Com Sarkari Naukri Latest Jobs Online Form at Sarkari Results 2024 </h1>

# %%
# check first H2
soup.h2
# Out:
# <h2><span style="color: #ff0000;"><strong>Welcome to No. 1 Education Portal Sarkari Result 2024</strong> <strong><span style="color: #008000;"> </span></strong></span> </h2>

# %%
tag=soup.html
type(tag)
# Out:
# bs4.element.Tag

# %%
 # tag
 tag=soup.p
 tag
# Out:
# <p> The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.</p>

# %%
tag=soup.h1
tag
# Out:
# <h1>Sarkari Result : SarkariResult.Com Sarkari Naukri Latest Jobs Online Form at Sarkari Results 2024 </h1>

# %% [markdown]
# **Navigable String**

# %%
tag=soup.p.string
tag
# Out:
# ' The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.'

# %%
tag=soup.a.string
tag
# Out:
# 'Home'

# %% [markdown]
# **Beautifull**

# %%
soup.name
soup.title
soup.head
# Out:
# <head><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <title>SarkariResult.com : Sarkari Results, Latest Online Form | Result 2024</title>
# <meta content="Sarkari Result, Sarkari Results : SarkariResult.com provides latest Sarkari Result Jobs, Online Form, Sarkari Naukri Result in Sarkari Result 2024 various sectors such as Railway, Bank, SSC, Navy, Police, UPPSC, UPSSSC, UPTET, UP Scholarship and other sarkari result Com alerts at one place सरकारी रिजल्ट  " name="description"/>
# <meta content="Sarkari Result, Sarkari Results, sarkari result 2024,  latest sarkari result, Sarkariresult, Sarkari, Sarkariresults, Sarkari Naukri, sarkari results 2023, sarkari result 2024, Sarkari Exam, SarkariResult.com" name="keywords"/>
# <meta content="general" name="rating">
# <meta content="en" http-equiv="content-language">
# <meta content="global" name="distribution">
# <meta content="index, follow" name="robots"/>
# ...

# %% [markdown]
# **Function and find ,findall**

# %%
soup.find("h1")
# Out:
# <h1>Sarkari Result : SarkariResult.Com Sarkari Naukri Latest Jobs Online Form at Sarkari Results 2024 </h1>

# %%
soup.find_all("h1")
# Out:
# [<h1>Sarkari Result : SarkariResult.Com Sarkari Naukri Latest Jobs Online Form at Sarkari Results 2024 </h1>]

# %%
# comments
com=soup.p.string
com
# Out:
# ' The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.'

# %%
com=soup.p.prettify()
com
# Out:
# '<p>\n The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.\n</p>\n'

# %%
# BY Class
soup.find_all('p')
# Out:
# [<p> The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.</p>,
#  <p> Did you know that over 1.5 million people lost their jobs in August 2021 in rural and urban India? Yes, the COVID-19 pandemic has hit the job market hard. Small businesses and multinationals alike have had to reconsider their staffing requirements.</p>,
#  <p> Are you an unemployed Indian citizen because of the pandemic and fluctuating job market?</p>,
#  <p> Are you working for a multinational company going through restructuring and considering your next steps?</p>,
#  <p> Are you a recent graduate looking to find your first job?</p>,
#  <p> Are you wondering if a government job is right for you?</p>,
#  <p> You've come to the right place! At Sarkari Result, we will show you the benefits of an Indian government job and help you to find a government job that's stable, long-term, and right for you! </p>,
# ...

# %%
soup.find_all('h1')
# Out:
# [<h1>Sarkari Result : SarkariResult.Com Sarkari Naukri Latest Jobs Online Form at Sarkari Results 2024 </h1>]

# %%
class_data=soup.find("div",class_="content_area")
class_data
# Out:
# <div class="content_area">
# <div class="container">
# <h2 class="heading">Sarkari Result : Resources to Help Indians Get Government Jobs (Sarkari Job)</h2>
# <p> The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.</p>
# <p> Did you know that over 1.5 million people lost their jobs in August 2021 in rural and urban India? Yes, the COVID-19 pandemic has hit the job market hard. Small businesses and multinationals alike have had to reconsider their staffing requirements.</p>
# <p> Are you an unemployed Indian citizen because of the pandemic and fluctuating job market?</p>
# <p> Are you working for a multinational company going through restructuring and considering your next steps?</p>
# <p> Are you a recent graduate looking to find your first job?</p>
# <p> Are you wondering if a government job is right for you?</p>
# ...

# %%
# by ID
id_data=soup.find_all("div",id="head-title")
id_data
# Out:
# [<div id="head-title">SARKARI RESULT<br/></div>]

# %%
# Extrct text from web in paragraph
line=soup.find_all("p")
line
# Out:
# [<p> The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.</p>,
#  <p> Did you know that over 1.5 million people lost their jobs in August 2021 in rural and urban India? Yes, the COVID-19 pandemic has hit the job market hard. Small businesses and multinationals alike have had to reconsider their staffing requirements.</p>,
#  <p> Are you an unemployed Indian citizen because of the pandemic and fluctuating job market?</p>,
#  <p> Are you working for a multinational company going through restructuring and considering your next steps?</p>,
#  <p> Are you a recent graduate looking to find your first job?</p>,
#  <p> Are you wondering if a government job is right for you?</p>,
#  <p> You've come to the right place! At Sarkari Result, we will show you the benefits of an Indian government job and help you to find a government job that's stable, long-term, and right for you! </p>,
# ...

# %%
for i in line:
  print(i.text)
# Out:
#  The future is uncertain, but a government job, Sarkari Jobs can help you secure your future. Click for valuable resources and help from Sarkari Result.
#  Did you know that over 1.5 million people lost their jobs in August 2021 in rural and urban India? Yes, the COVID-19 pandemic has hit the job market hard. Small businesses and multinationals alike have had to reconsider their staffing requirements.
#  Are you an unemployed Indian citizen because of the pandemic and fluctuating job market?
#  Are you working for a multinational company going through restructuring and considering your next steps?
#  Are you a recent graduate looking to find your first job?
#  Are you wondering if a government job is right for you?
#  You've come to the right place! At Sarkari Result, we will show you the benefits of an Indian government job and help you to find a government job that's stable, long-term, and right for you!
# ...

# %%
S=soup.find("div",class_="text-center clearfix")
S
# Out:
# <div class="text-center clearfix" id="header">
# <div class="logo"><img alt="" src="/images/logo-new.png"/></div>
# <div id="head-title">SARKARI RESULT<br/></div>
# <font color="#ffffff" size="+1"><b>WWW.SARKARIRESULT.COM</b></font>
# </div>

# %%
S.text
# Out:
# '\n\nSARKARI RESULT\nWWW.SARKARIRESULT.COM\n'

# %%
lines=S.find_all("p")
lines
# Out:
# []

# %%
for  i in lines:
  print(i.text)

# %%
web
# Out:
# <Response [200]>

# %% [markdown]
# **# extracting Link from the web**

# %%
:
#web=requests.get("https://www.magicbricks.com/property-for-sale/residential-real-estate?bedroom=&proptype=Multistorey-Apartment,Builder-Floor-Apartment,Penthouse,Studio-Apartment&cityName=Pune")
soup=BeautifulSoup(web.content,"html.parser")
print(soup.prettify())
soup.find_all("a")
for i in soup.find_all("a"):
  print(i.get("href"))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    Flats for Sale in Pune: Check 48227+ Apartments / Flats in Pune
#   </title>
#   <link href="https://fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="https://cdn.staticmb.com" rel="preconnect"/>
#   <link href="https://img.staticmb.com" rel="preconnect"/>
#   <link href="https://www.googletagmanager.com" rel="dns-prefetch"/>
#   <link href="https://www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://cdn.staticmb.com/images/favicon.ico" rel="shortcut icon"/>
#   <meta content="Find over 48227+ Flats in Pune for sale only at MagicBricks. Choose from Owner Properties &amp;  Verified Flats Listings with option of 2 BHK, 3 BHK, 4 BHK apartments in Pune. " name="description"/>
# ...

# %% [markdown]
# **# Extractig Img:**

# %%
img=soup.find_all('img')
img
# Out:
# [<img alt="Buy 2 BHK Flat for Sale in  Mahalunge Pune" class="mb-srp__card__photo__fig--graphic" decoding="async" height="100%" src="https://img.staticmb.com/mbphoto/property/cropped_images/2023/Aug/20/Photo_h300_w450/68688829_14_rojectPhoto32ItrendFuturaPune540679112001600_300_450.jpg" title="Buy 2 BHK Flat for Sale in  Mahalunge Pune" width="100%"/>,
#  <img alt="Buy 2 BHK Flat for Sale in  Marunji, Hinjawadi Pune" class="mb-srp__card__photo__fig--graphic" decoding="async" height="100%" src="https://img.staticmb.com/mbphoto/property/cropped_images/2023/Apr/06/Photo_h300_w450/63572489_7_rojectPhoto15ParkTitanPune5325359600800_300_450.jpg" title="Buy 2 BHK Flat for Sale in  Marunji, Hinjawadi Pune" width="100%"/>,
# ...

# %%
for i in img:
  print(i.get("src"))
# Out:
# https://img.staticmb.com/mbphoto/property/cropped_images/2023/Aug/20/Photo_h300_w450/68688829_14_rojectPhoto32ItrendFuturaPune540679112001600_300_450.jpg
# https://img.staticmb.com/mbphoto/property/cropped_images/2023/Apr/06/Photo_h300_w450/63572489_7_rojectPhoto15ParkTitanPune5325359600800_300_450.jpg
# https://img.staticmb.com/mbimages/project/Photo_h310_w462/2023/01/23/Project-Photo-6-Kohinoor-Westview-Reserve-Pune-5391567_1200_1600_310_462.jpg
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# data:image/svg+xml;base64,...
# ...
